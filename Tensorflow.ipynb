# %% [markdown]
# <a href="https://colab.research.google.com/github/SANTHOSH-C08/AI-INTERNSHIP/blob/main/Tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
mnist = keras.datasets.mnist
(x_train , y_train) , (x_test , y_test) = mnist.load_data()
x_train , x_test = x_train / 255.0 , x_test / 255.0
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[54444])

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28,1)) ,
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history=model.fit(x_train, y_train,validation_split=0.1, epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9219 - loss: 0.2754 - val_accuracy: 0.9663 - val_loss: 0.1226
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9649 - loss: 0.1203 - val_accuracy: 0.9738 - val_loss: 0.0850
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9756 - loss: 0.0818 - val_accuracy: 0.9752 - val_loss: 0.0831
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9815 - loss: 0.0611 - val_accuracy: 0.9768 - val_loss: 0.0773
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9857 - loss: 0.0469 - val_accuracy: 0.9782 - val_loss: 0.0775
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9886 - loss: 0.0368 - val_accuracy: 0.9788 - val_loss: 0.0729
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9913 - loss: 0.0293 - val_accuracy: 0.9787 - val_loss: 0.0707
# Epoch 8/10
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy Model')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['training data','validation data'],loc='upper right')

# %%
y_pred = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
y_pred[8888]
# Out:
# array([1.0450593e-10, 1.2690049e-12, 4.2863778e-08, 1.3483088e-11,
#        4.2314452e-10, 6.5470958e-13, 9.9999994e-01, 8.1930764e-17,
#        7.4361324e-12, 4.2695762e-16], dtype=float32)

# %%
import numpy as np
y_pred1 = np.argmax(y_pred , axis = 1)
y_pred1[8888]
# Out:
# np.int64(6)

# %%
import numpy as np
import matplotlib.pyplot as plt

y_pred_classes = np.argmax(y_pred, axis=1)

plt.imshow(x_test[9].reshape(28,28), cmap='gray')
plt.title(f"y_test = {y_test[9]}, y_pred = {y_pred_classes[9]}")
plt.axis('off')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/2.jpeg', cv2.IMREAD_GRAYSCALE)

plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.axis('off')
plt.show()

# %%
model.save('')
